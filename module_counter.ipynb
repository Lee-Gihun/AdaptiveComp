# %%
import torch
from train_tools.utils import counter

from models.EP_modules.SCAN import SCAN
from models.EP_modules.EPE import EPE

print('<SCAN Result>')
model = SCAN(channels=256, final_channels=512, stride=2, num_classes=100, conf_type='sr', selection_type='selection7')
sample = torch.randn(4, 256, 8, 8)
params, flops = counter(model, sample, verbose=False)
print('------------------------------------------------')

print('<EPE Result>')
model = EPE(channels=256, final_channels=512, stride=2, num_classes=100, conf_type='sr', selection_type='selection7')
sample = torch.randn(4, 256, 8, 8)
params, flops = counter(model, sample, verbose=False)
print('------------------------------------------------')
# Out:
# <SCAN Result>
# Input size: (4, 256, 8, 8)
# 55,271,424 FLOPs or approx. 0.06 GFLOPs
# flops: 55.2714M, params: 1.8574M
# ------------------------------------------------
# <EPE Result>
# 51
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-93035342cb2f> in <module>
#      14 model = EPE(channels=256, final_channels=512, stride=2, num_classes=100, conf_type='sr', selection_type='selection7')
#      15 sample = torch.randn(4, 256, 8, 8)
# ---> 16 params, flops = counter(model, sample, verbose=False)
#      17 print('------------------------------------------------')
#
# ~/jupyter/old_servers/AdaptiveComp/train_tools/utils.py in counter(model, sample, verbose)
#     214         params_num += params.view(-1).shape[0]
#     215
# --> 216     flops = count_ops(model, sample, verbose=verbose)
# ...

# %%
import math

def _target_setter(position_flops, base=0.25):
    hard_target = []
        
    for F_i in position_flops:
        target = min(math.sin(base+math.sin(F_i*math.pi/2)), 1)
        hard_target.append(target)
        
    return hard_target


_target_setter([0.35217])
# Out:
# [0.7000031138377726]
